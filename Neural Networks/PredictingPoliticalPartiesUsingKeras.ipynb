# %% [markdown]
# # Predicitng political party based on votes

# %%
import pandas as pd

feature_names=['party','handicapped-infants', 'water-project-cost-sharing', 
                    'adoption-of-the-budget-resolution', 'physician-fee-freeze',
                    'el-salvador-aid', 'religious-groups-in-schools',
                    'anti-satellite-test-ban', 'aid-to-nicaraguan-contras',
                    'mx-missle', 'immigration', 'synfuels-corporation-cutback',
                    'education-spending', 'superfund-right-to-sue', 'crime',
                    'duty-free-exports', 'export-administration-act-south-africa']
voting_data=pd.read_csv('house-votes-84.data.txt',na_values=['?'],names=feature_names)
voting_data.head()
# Out:
#         party handicapped-infants water-project-cost-sharing  \
# 0  republican                   n                          y
# 1  republican                   n                          y
# 2    democrat                 NaN                          y
# 3    democrat                   n                          y
# 4    democrat                   y                          y
#
#   adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                  NaN               y
# 3                                 y                    n             NaN
# 4                                 y                    n               y
#
#   religious-groups-in-schools anti-satellite-test-ban  \
# 0                           y                       n
# ...

# %%
voting_data.describe()
# Out:
#            party handicapped-infants water-project-cost-sharing  \
# count        435                 423                        387
# unique         2                   2                          2
# top     democrat                   n                          y
# freq         267                 236                        195
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# count                                424                  424             420
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 253                  247             212
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          424                     421
# unique                           2                       2
# top                              y                       y
# ...

# %%
voting_data.dropna(inplace=True)
voting_data.describe()
# Out:
#            party handicapped-infants water-project-cost-sharing  \
# count        232                 232                        232
# unique         2                   2                          2
# top     democrat                   n                          n
# freq         124                 136                        125
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# count                                232                  232             232
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 123                  119             128
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          232                     232
# unique                           2                       2
# top                              y                       y
# ...

# %%
voting_data.replace(('y','n'),(1,0),inplace=True)
voting_data.replace(('democrat','republican'),(1,0),inplace=True)
voting_data.head()
# Out:
#     party  handicapped-infants  water-project-cost-sharing  \
# 5       1                    0                           1
# 8       0                    0                           1
# 19      1                    1                           1
# 23      1                    1                           1
# 25      1                    1                           0
#
#     adoption-of-the-budget-resolution  physician-fee-freeze  el-salvador-aid  \
# 5                                   1                     0                1
# 8                                   0                     1                1
# 19                                  1                     0                0
# 23                                  1                     0                0
# 25                                  1                     0                0
#
#     religious-groups-in-schools  anti-satellite-test-ban  \
# 5                             1                        0
# ...

# %% [markdown]
# Extracting the features and labels in the format that keras expects:

# %%
all_features=voting_data[feature_names].drop('party',axis=1).values
all_classes=voting_data['party'].values

# %% [markdown]
# Setting up the neural network.

# %%
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import cross_val_score
from scikeras.wrappers import KerasClassifier

# %%
def create_model():
    model=Sequential()
    #16 feature inputs going into 32-unit layer
    model.add(Dense(32, input_dim=16, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    #output layer with a binary classifier
    model.add(Dense(1,kernel_initializer='normal', activation='sigmoid'))
    #compiling the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

#wrap the model in an estimator compatible with scikit_learn
estimator = KerasClassifier(model=create_model, loss='binary_crossentropy', epochs=100, verbose=0)
#evaluating the accuracy
cv_scores = cross_val_score(estimator, all_features, all_classes, cv=10)
cv_scores.mean()
# Out:
# 0.9568840579710146
